# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/shipments.csv')
print(df.head())
print(f"\nВсего записей: {len(df)}")
# Out:
#    shipment_id     from_city          to_city  distance_km  weight_kg  \
# 0            1        Москва  Санкт-Петербург          710        500
# 1            2  Екатеринбург      Новосибирск         1500       1200
# 2            3        Казань           Москва          800        800
# 3            4   Новосибирск       Красноярск          800        600
# 4            5        Москва           Казань          800        750
#
#    cost_rub        date        carrier
# 0     15000  2024-01-15  Деловые Линии
# 1     32000  2024-01-16            ПЭК
# 2     18000  2024-01-16  Деловые Линии
# 3     17000  2024-01-17            ЖДД
# 4     17500  2024-01-17            ПЭК
#
# Всего записей: 10

# %%
df.groupby('carrier')['cost_rub'].sum().plot(kind='bar', title='Общая стоимость по перевозчикам')
plt.ylabel('Стоимость, руб')
plt.tight_layout()
plt.show()
